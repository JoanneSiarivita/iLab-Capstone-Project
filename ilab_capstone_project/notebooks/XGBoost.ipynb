# %% [markdown]
# # *Data preparation for modelling*

# %%
#Launch commands to automatically reload modules
# %load_ext autoreload
# %autoreload 2

# %%
#Load libraries to use
import pandas as pd

# %%
#Load dataset into a dataframe
data = pd.read_csv('../data/raw/GlobalDietaryDatabase_V2.csv')

# %%
# Define the list of relevant features
features_target_list = ['Fruits', 'Non-starchy vegetables', 'Potatoes', 'Other starchy vegetables', 'Beans and legumes',
    'Nuts and seeds', 'Refined grains', 'Whole grains', 'Total processed meats', 'Unprocessed red meats',
    'Total seafoods', 'Eggs', 'Cheese', 'Yoghurt (including fermented milk)', 'Sugar-sweetened beverages',
    'Fruit juices', 'Coffee', 'Tea', 'Total carbohydrates', 'Total protein', 'Saturated fat',
    'Monounsaturated fatty acids', 'Total omega-6 fat', 'Seafood omega-3 fat', 'Plant omega-3 fat',
    'Dietary fiber', 'Added sugars', 'Calcium', 'Dietary sodium', 'Iodine', 'Iron', 'Magnesium',
    'Potassium', 'Selenium', 'Vitamin A w/ supplements', 'Vitamin B1', 'Vitamin B2', 'Vitamin B3',
    'Vitamin B6', 'Vitamin B9 (Folate)', 'Vitamin B12', 'Vitamin C', 'Vitamin D', 'Vitamin E', 'Zinc',
    'Total Milk', 'ObesityRate']

# Subset the dataframe to include only the relevant features
subset_diet = data[features_target_list]

# Display the subsetted dataframe
subset_diet.head()
# Out:
#        Fruits  Non-starchy vegetables    Potatoes  Other starchy vegetables
# 0   65.697036               98.080124   21.195808                 44.892140  \
# 1  119.746980              308.837004  346.377109                 52.662482
# 2  138.874360              129.083757  185.783632                 73.031694
# 3  107.577820              123.284747  182.972287                 57.068126
# 4   93.995787              123.803276   51.336122                  7.010755
#
#    Beans and legumes  Nuts and seeds  Refined grains  Whole grains
# 0         103.830266       31.205695      223.168905     41.528924  \
# 1          37.799557       11.612246      223.838504     57.592403
# 2          40.181361       12.272771      252.814018     31.213772
# 3          40.563807       31.729379      337.642299     37.176284
# 4           3.575009        1.564769      174.327695     10.813137
#
#    Total processed meats  Unprocessed red meats  ...  Vitamin B3  Vitamin B6
# 0               2.238317               8.686127  ...   13.506114    1.104237  \
# 1               1.834424              17.956861  ...   13.458252    1.674145
# 2              73.437068              67.946539  ...   29.577227    2.299154
# 3              38.369565              29.418572  ...   23.532757    1.363786
# 4              24.181776              87.927046  ...   18.262302    1.225320
#
#    Vitamin B9 (Folate)  Vitamin B12   Vitamin C  Vitamin D  Vitamin E
# 0           190.395113     1.799365   42.126845   1.594519   6.426413  \
# 1           266.296534     2.385507  179.500622   1.717556   7.970200
# 2           269.593547     3.877962  128.673375   5.063677  15.171798
# 3           419.596541     3.072174   84.865840   2.197133   7.379018
# 4           440.697491     4.255942   53.516605   2.608307   8.424583
#
#        Zinc  Total Milk  ObesityRate
# 0  7.644691   69.785193        18.19
# 1  7.274286   32.784132        11.11
# 2  7.995075  113.739785        22.69
# 3  8.514326  129.185734        32.02
# 4  9.163603  136.438275        34.37
#
# [5 rows x 47 columns]

# %% [markdown]
# # **Build pipeline**

# %%
#Import pipeline package
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error, r2_score
from joblib import dump
